# %%
import pandas as pd

# %%
df1 = pd.read_excel('test.xlsx')

# %%
df1
# Out:
#     S/N  Age
# 0     1   33
# 1     2   50
# 2     3   26
# 3     4   63
# 4     5   80
# 5     6   77
# 6     7   13
# 7     8   73
# 8     9   87
# 9    10   42
# 10   11   38
# 11   12   89
# 12   13   27

# %%
df2 = pd.read_excel('test.xlsx', sheet_name=1)

# %%
df2
# Out:
#     S/N  Weight
# 0     1      70
# 1     2      32
# 2     3      47
# 3     4      42
# 4     5      54
# 5     6      90
# 6     7      15
# 7     8      89
# 8     9      67
# 9    10      21
# 10   11      71
# 11   12      70
# 12   13      83

# %%
df3 = pd.read_excel('test.xlsx', sheet_name = 'ages')

# %%
df3
# Out:
#      a  Age
# 0    1   33
# 1    2   50
# 2    3   26
# 3    4   63
# 4    5   80
# 5    6   77
# 6    7   13
# 7    8   73
# 8    9   87
# 9   10   42
# 10  11   38
# 11  12   89
# 12  13   27

# %%
dfs = pd.read_excel('test.xlsx', sheet_name = [0,1])  #to extract 2 spreadsheets

# %%
dfs
# Out:
# {0:      a  Age
#  0    1   33
#  1    2   50
#  2    3   26
#  3    4   63
#  4    5   80
#  5    6   77
#  6    7   13
#  7    8   73
#  8    9   87
#  9   10   42
#  10  11   38
#  11  12   89
#  12  13   27,
#  1:     S/N  Weight
#  0     1      70
#  1     2      32
#  2     3      47
#  3     4      42
#  4     5      54
#  5     6      90
#  6     7      15
#  7     8      89
#  8     9      67
#  9    10      21
#  10   11      71
#  11   12      70
#  12   13      83}

# %%
dfs[0]
# Out:
#      a  Age
# 0    1   33
# 1    2   50
# 2    3   26
# 3    4   63
# 4    5   80
# 5    6   77
# 6    7   13
# 7    8   73
# 8    9   87
# 9   10   42
# 10  11   38
# 11  12   89
# 12  13   27

# %%
dfs[1]
# Out:
#     S/N  Weight
# 0     1      70
# 1     2      32
# 2     3      47
# 3     4      42
# 4     5      54
# 5     6      90
# 6     7      15
# 7     8      89
# 8     9      67
# 9    10      21
# 10   11      71
# 11   12      70
# 12   13      83

# %%
df1
# Out:
#     S/N  Age
# 0     1   33
# 1     2   50
# 2     3   26
# 3     4   63
# 4     5   80
# 5     6   77
# 6     7   13
# 7     8   73
# 8     9   87
# 9    10   42
# 10   11   38
# 11   12   89
# 12   13   27

# %%
df1['mod age'] = df1['Age'] + 20.5

# %%
df1
# Out:
#     S/N  Age  mod age
# 0     1   33     53.5
# 1     2   50     70.5
# 2     3   26     46.5
# 3     4   63     83.5
# 4     5   80    100.5
# 5     6   77     97.5
# 6     7   13     33.5
# 7     8   73     93.5
# 8     9   87    107.5
# 9    10   42     62.5
# 10   11   38     58.5
# 11   12   89    109.5
# 12   13   27     47.5

# %% [markdown]
# ## Save tha dataset

# %%
#create an excel writer
file= pd.ExcelWriter('my result.xlsx')

# %%
file

# %%
#save dataframe to excel writer
df1.to_excel(file)

# %%
file.save()

# %%
df1.to_excel(file)
