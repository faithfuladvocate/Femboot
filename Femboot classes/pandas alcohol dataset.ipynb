# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('drinks.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-18b3500d0017> in <module>
# ----> 1 df = pd.read_csv('drinks.csv')
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
# ...

# %%
df = pd.read_csv('./titanic-dataset/drinks.csv')

# %%
df.set_index('country')
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
# ...                    ...              ...            ...
# Venezuela              333              100              3
# Vietnam                111                2              1
# Yemen                    6                0              0
# Zambia                  32               19              4
# Zimbabwe                64               18              4
#
#              total_litres_of_pure_alcohol      continent
# country
# Afghanistan                           0.0           Asia
# Albania                               4.9         Europe
# Algeria                               0.7         Africa
# ...

# %%
df.set_index(['country', 'continent'])
# Out:
#                            beer_servings  spirit_servings  wine_servings  \
# country     continent
# Afghanistan Asia                       0                0              0
# Albania     Europe                    89              132             54
# Algeria     Africa                    25                0             14
# Andorra     Europe                   245              138            312
# Angola      Africa                   217               57             45
# ...                                  ...              ...            ...
# Venezuela   South America            333              100              3
# Vietnam     Asia                     111                2              1
# Yemen       Asia                       6                0              0
# Zambia      Africa                    32               19              4
# Zimbabwe    Africa                    64               18              4
#
#                            total_litres_of_pure_alcohol
# ...

# %%
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
df.sort_index
# Out:
# <bound method DataFrame.sort_index of          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
df.set_index(['continent', 'country']).sort_index()
# Out:
#                             beer_servings  spirit_servings  wine_servings  \
# continent     country
# Africa        Algeria                  25                0             14
#               Angola                  217               57             45
#               Benin                    34                4             13
#               Botswana                173               35             35
#               Burkina Faso             25                7              7
# ...                                   ...              ...            ...
# South America Paraguay                213              117             74
#               Peru                    163              160             21
#               Suriname                128              178              7
#               Uruguay                 115               35            220
#               Venezuela               333              100              3
#
#                             total_litres_of_pure_alcohol
# ...

# %%
df2 = df.set_index(['continent', 'country']).sort_index()

# %%
df2.head()
# Out:
#                         beer_servings  spirit_servings  wine_servings  \
# continent country
# Africa    Algeria                  25                0             14
#           Angola                  217               57             45
#           Benin                    34                4             13
#           Botswana                173               35             35
#           Burkina Faso             25                7              7
#
#                         total_litres_of_pure_alcohol
# continent country
# Africa    Algeria                                0.7
#           Angola                                 5.9
#           Benin                                  1.1
#           Botswana                               5.4
#           Burkina Faso                           4.3

# %%
df['continent']
# Out:
# 0               Asia
# 1             Europe
# 2             Africa
# 3             Europe
# 4             Africa
#            ...
# 188    South America
# 189             Asia
# 190             Asia
# 191           Africa
# 192           Africa
# Name: continent, Length: 193, dtype: object

# %%
df['continent'] == 'Africa'
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 188    False
# 189    False
# 190    False
# 191     True
# 192     True
# Name: continent, Length: 193, dtype: bool

# %%
df[df['continent'] == 'Africa'] #Just Africa
# Out:
#                       country  beer_servings  spirit_servings  wine_servings  \
# 2                     Algeria             25                0             14
# 4                      Angola            217               57             45
# 18                      Benin             34                4             13
# 22                   Botswana            173               35             35
# 26               Burkina Faso             25                7              7
# 27                    Burundi             88                0              0
# 28              Cote d'Ivoire             37                1              7
# 29                 Cabo Verde            144               56             16
# 31                   Cameroon            147                1              4
# 33   Central African Republic             17                2              1
# 34                       Chad             15                1              1
# ...

# %%
df_Africa = df[df['continent'] == 'Africa']

# %%
df_Africa.shape
# Out:
# (53, 6)

# %%
df_Africa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53 entries, 2 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       53 non-null     object
#  1   beer_servings                 53 non-null     int64
#  2   spirit_servings               53 non-null     int64
#  3   wine_servings                 53 non-null     int64
#  4   total_litres_of_pure_alcohol  53 non-null     float64
#  5   continent                     53 non-null     object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 2.9+ KB

# %%
df_Africa['country'] == 'Nigeria'
# Out:
# 2      False
# 4      False
# 18     False
# 22     False
# 26     False
# 27     False
# 28     False
# 29     False
# 31     False
# 33     False
# 34     False
# 38     False
# 39     False
# 47     False
# 49     False
# 53     False
# 55     False
# 56     False
# 58     False
# 62     False
# 63     False
# 66     False
# 70     False
# 71     False
# 88     False
# 95     False
# 96     False
# 97     False
# 100    False
# 101    False
# 104    False
# 107    False
# 108    False
# 114    False
# 115    False
# 117    False
# 123    False
# 124     True
# 142    False
# 148    False
# 150    False
# 152    False
# 153    False
# 158    False
# 159    False
# 162    False
# 164    False
# 172    False
# 175    False
# 179    False
# 183    False
# 191    False
# 192    False
# Name: country, dtype: bool

# %%
df_Africa[df_Africa['country'] == 'Nigeria']
# Out:
#      country  beer_servings  spirit_servings  wine_servings  \
# 124  Nigeria             42                5              2
#
#      total_litres_of_pure_alcohol continent
# 124                           9.1    Africa

# %%
df_Nigeria = df_Africa[df_Africa['country'] == 'Nigeria']

# %%
df_Nigeria.plot()
# Out:
# <AxesSubplot:>

# %%
df_Nigeria.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df_Nigeria.set_index('country')
# Out:
#          beer_servings  spirit_servings  wine_servings  \
# country
# Nigeria             42                5              2
#
#          total_litres_of_pure_alcohol continent
# country
# Nigeria                           9.1    Africa

# %%
df_Nigeria.set_index('country').plot(kind='bar') #method chaining
# Out:
# <AxesSubplot:xlabel='country'>

# %% [markdown]
# # exploratory data analysis,EDA: what is going on with the data?
# # descriptive data analysis : what can i say about the data?
# # prescriptive data analysis: what can be done to avert an issue in the data?
# # forcasting/ predictive data analysis (machine learning): how will the future of this data be like?
