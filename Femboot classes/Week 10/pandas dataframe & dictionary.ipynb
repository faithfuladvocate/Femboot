# %% [markdown]
# ## Dataframe object

# %%
import pandas as pd

# %%
import numpy as np

# %%
np.array([3,4,5,6])
# Out:
# array([3, 4, 5, 6])

# %%
pd.Series([3,4,5,6])
# Out:
# 0    3
# 1    4
# 2    5
# 3    6
# dtype: int64

# %%
pd.Series([[3,4,5,6], [4,5,5,6]])
# Out:
# 0    [3, 4, 5, 6]
# 1    [4, 5, 5, 6]
# dtype: object

# %%
pd.DataFrame([[3,4,5,6], [4,5,5,6]])
# Out:
#    0  1  2  3
# 0  3  4  5  6
# 1  4  5  5  6

# %%
pd.DataFrame([[3,4,5,6], [4,5,5,6], [3,4,4,3]])
# Out:
#    0  1  2  3
# 0  3  4  5  6
# 1  4  5  5  6
# 2  3  4  4  3

# %%
df = pd.DataFrame([[3,4,5,6], [4,5,5,6], [3,4,4,3]])

# %%
df
# Out:
#    0  1  2  3
# 0  3  4  5  6
# 1  4  5  5  6
# 2  3  4  4  3

# %%
df.index = [1,2,3]

# %%
df #index(row), column
# Out:
#    0  1  2  3
# 1  3  4  5  6
# 2  4  5  5  6
# 3  3  4  4  3

# %%
df.columns = ['CSC 210', 'CSC 410', 'NSG 502', 'NSG 418']

# %%
df
# Out:
#    CSC 210  CSC 410  NSG 502  NSG 418
# 1        3        4        5        6
# 2        4        5        5        6
# 3        3        4        4        3

# %%
df.index = ['stu1', 'stu2', 'stu3']

# %%
df
# Out:
#       CSC 210  CSC 410  NSG 502  NSG 418
# stu1        3        4        5        6
# stu2        4        5        5        6
# stu3        3        4        4        3

# %% [markdown]
# ## Dictionary

# %%
# [4,5,4,5]

ages = {
    'smith': 23,
    'Mirabelle': 45,
    'Faithful': 24,
    'Aniema': 34
}

# %%
type(ages)
# Out:
# dict

# %%
ages.keys()
# Out:
# dict_keys(['smith', 'Mirabelle', 'Faithful', 'Aniema'])

# %%
ages.values()
# Out:
# dict_values([23, 45, 24, 34])

# %%
df1 = pd.DataFrame(ages)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-7c571116646a> in <module>
# ----> 1 df1 = pd.DataFrame(ages)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#     470             import numpy.ma.mrecords as mrecords
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     281             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     282         ]
# --> 283     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     284
#     285
#
# ...

# %%
df1 = pd.DataFrame(ages, index = [1,2,3,4])

# %%
df1
# Out:
#    smith  Mirabelle  Faithful  Aniema
# 1     23         45        24      34
# 2     23         45        24      34
# 3     23         45        24      34
# 4     23         45        24      34

# %%
df1 = pd.DataFrame(ages, index = [1])

# %%
df1
# Out:
#    smith  Mirabelle  Faithful  Aniema
# 1     23         45        24      34

# %%
df1 = pd.DataFrame(ages, index = [1,3])

# %%
df1
# Out:
#    smith  Mirabelle  Faithful  Aniema
# 1     23         45        24      34
# 3     23         45        24      34

# %%
# import numpy as np
dict2 = {
    'Country' : ['Nigeria', 'South Africa', 'Afghanistan'],
    'Landmark' : np.random.randint(2000,200000,3),
    'Population' : np.random.randint(40000,400000,3)
}

# %%
dict2
# Out:
# {'Country': ['Nigeria', 'South Africa', 'Afghanistan'],
#  'Landmark': array([120035,  65124, 164839]),
#  'Population': array([357151, 258425, 387716])}

# %%
pd.DataFrame(dict2)
# Out:
#         Country  Landmark  Population
# 0       Nigeria    120035      357151
# 1  South Africa     65124      258425
# 2   Afghanistan    164839      387716

# %% [markdown]
# ## importing external data

# %%
data = pd.read_csv('titanic.csv')
#data = pd.read_csv('C:\Users\faith\Documents\Femboot 2021\Femboot-Github\Femboot classes\Week 10\titanic.csv')

# %%
data
# Out:
#      passenger_id  pclass                                               name  \
# 0            1216       3                                 Smyth, Miss. Julia
# 1             699       3                                    Cacic, Mr. Luka
# 2            1267       3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 3             449       2              Hocking, Mrs. Elizabeth (Eliza Needs)
# 4             576       2                                    Veal, Mr. James
# ..            ...     ...                                                ...
# 845           158       1                        Hipkins, Mr. William Edward
# 846           174       1                            Kent, Mr. Edward Austin
# 847           467       2                Kantor, Mrs. Sinai (Miriam Sternin)
# 848          1112       3                          Peacock, Miss. Treasteall
# 849           425       2                              Greenberg, Mr. Samuel
#
# ...

# %%
data.head() ## default first 5
# Out:
#    passenger_id  pclass                                               name  \
# 0          1216       3                                 Smyth, Miss. Julia
# 1           699       3                                    Cacic, Mr. Luka
# 2          1267       3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 3           449       2              Hocking, Mrs. Elizabeth (Eliza Needs)
# 4           576       2                                    Veal, Mr. James
#
#       sex   age  sibsp  parch  ticket     fare cabin embarked boat  survived  \
# 0  female   NaN      0      0  335432   7.7333   NaN        Q   13         1
# 1    male  38.0      0      0  315089   8.6625   NaN        S  NaN         0
# 2  female  30.0      1      1  345773  24.1500   NaN        S  NaN         0
# 3  female  54.0      1      3   29105  23.0000   NaN        S    4         1
# 4    male  40.0      0      0   28221  13.0000   NaN        S  NaN         0
#
#                   home.dest
# ...

# %%
data.tail() ##default is last 5
# Out:
#      passenger_id  pclass                                 name     sex   age  \
# 845           158       1          Hipkins, Mr. William Edward    male  55.0
# 846           174       1              Kent, Mr. Edward Austin    male  58.0
# 847           467       2  Kantor, Mrs. Sinai (Miriam Sternin)  female  24.0
# 848          1112       3            Peacock, Miss. Treasteall  female   3.0
# 849           425       2                Greenberg, Mr. Samuel    male  52.0
#
#      sibsp  parch              ticket    fare cabin embarked boat  survived  \
# 845      0      0                 680  50.000   C39        S  NaN         0
# 846      0      0               11771  29.700   B37        C  NaN         0
# 847      1      0              244367  26.000   NaN        S   12         1
# 848      1      1  SOTON/O.Q. 3101315  13.775   NaN        S  NaN         0
# 849      0      0              250647  13.000   NaN        S  NaN         0
#
#                home.dest
# ...

# %%
data.head(10)
# Out:
#    passenger_id  pclass                                               name  \
# 0          1216       3                                 Smyth, Miss. Julia
# 1           699       3                                    Cacic, Mr. Luka
# 2          1267       3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 3           449       2              Hocking, Mrs. Elizabeth (Eliza Needs)
# 4           576       2                                    Veal, Mr. James
# 5          1083       3                           Olsen, Mr. Henry Margido
# 6           898       3                    Johnson, Mr. William Cahoone Jr
# 7           560       2                              Sinkkonen, Miss. Anna
# 8          1079       3                                 Ohman, Miss. Velin
# 9           908       3                           Jussila, Miss. Mari Aina
#
#       sex   age  sibsp  parch  ticket     fare cabin embarked boat  survived  \
# ...

# %%
data.sample(4) #to randomly pick 4 items
# Out:
#      passenger_id  pclass                                       name     sex  \
# 132           186       1  Lindstrom, Mrs. Carl Johan (Sigrid Posse)  female
# 697           996       3                         Markun, Mr. Johann    male
# 75            821       3                  Goldsmith, Mr. Frank John    male
# 711           353       2        Bryhl, Miss. Dagmar Jenny Ingeborg   female
#
#       age  sibsp  parch  ticket     fare cabin embarked boat  survived  \
# 132  55.0      0      0  112377  27.7208   NaN        C    6         1
# 697  33.0      0      0  349257   7.8958   NaN        S  NaN         0
# 75   33.0      1      1  363291  20.5250   NaN        S  NaN         0
# 711  20.0      1      0  236853  26.0000   NaN        S   12         1
#
#                              home.dest
# 132                  Stockholm, Sweden
# 697                                NaN
# 75   Strood, Kent, England Detroit, MI
# 711       Skara, Sweden / Rockford, IL

# %%
data.sample(3,random_state = 5) #similar to random seed
# Out:
#      passenger_id  pclass                                        name     sex  \
# 510           936       3  Kink-Heilmann, Mrs. Anton (Luise Heilmann)  female
# 352           701       3                            Calic, Mr. Petar    male
# 580           207       1                      Minahan, Miss. Daisy E  female
#
#       age  sibsp  parch  ticket     fare cabin embarked boat  survived  \
# 510  26.0      1      1  315153  22.0250   NaN        S    2         1
# 352  17.0      0      0  315086   8.6625   NaN        S  NaN         0
# 580  33.0      1      0   19928  90.0000   C78        Q   14         1
#
#          home.dest
# 510            NaN
# 352            NaN
# 580  Green Bay, WI

# %%
data['sex']
# Out:
# 0      female
# 1        male
# 2      female
# 3      female
# 4        male
#         ...
# 845      male
# 846      male
# 847    female
# 848    female
# 849      male
# Name: sex, Length: 850, dtype: object

# %%
data['age'].head() #first 5 data of age
# Out:
# 0     NaN
# 1    38.0
# 2    30.0
# 3    54.0
# 4    40.0
# Name: age, dtype: float64

# %%
data.info()  # meta data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 850 entries, 0 to 849
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   passenger_id  850 non-null    int64
#  1   pclass        850 non-null    int64
#  2   name          850 non-null    object
#  3   sex           850 non-null    object
#  4   age           676 non-null    float64
#  5   sibsp         850 non-null    int64
#  6   parch         850 non-null    int64
#  7   ticket        850 non-null    object
#  8   fare          849 non-null    float64
#  9   cabin         191 non-null    object
#  10  embarked      849 non-null    object
#  11  boat          308 non-null    object
#  12  survived      850 non-null    int64
#  13  home.dest     464 non-null    object
# dtypes: float64(2), int64(5), object(7)
# memory usage: 93.1+ KB

# %%
data.describe()
# Out:
#        passenger_id     pclass         age       sibsp       parch  \
# count    850.000000  850.00000  676.000000  850.000000  850.000000
# mean     662.816471    2.32000   29.519847    0.522353    0.382353
# std      380.751936    0.83853   14.562243    1.112132    0.879511
# min        1.000000    1.00000    0.166700    0.000000    0.000000
# 25%      332.250000    2.00000   20.000000    0.000000    0.000000
# 50%      676.500000    3.00000   28.000000    0.000000    0.000000
# 75%      992.250000    3.00000   37.000000    1.000000    0.000000
# max     1307.000000    3.00000   80.000000    8.000000    9.000000
#
#              fare    survived
# count  849.000000  850.000000
# mean    34.012701    0.368235
# std     53.705779    0.482610
# min      0.000000    0.000000
# 25%      7.895800    0.000000
# 50%     14.108300    0.000000
# 75%     31.000000    1.000000
# max    512.329200    1.000000
