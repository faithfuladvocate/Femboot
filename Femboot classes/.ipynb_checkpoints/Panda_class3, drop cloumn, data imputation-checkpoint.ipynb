# %%
import pandas as pd

# %%
df = pd.read_csv('titanic.csv')

# %%
df.head()
# Out:
#    passenger_id  pclass                                               name  \
# 0          1216       3                                 Smyth, Miss. Julia
# 1           699       3                                    Cacic, Mr. Luka
# 2          1267       3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 3           449       2              Hocking, Mrs. Elizabeth (Eliza Needs)
# 4           576       2                                    Veal, Mr. James
#
#       sex   age  sibsp  parch  ticket     fare cabin embarked boat  survived  \
# 0  female   NaN      0      0  335432   7.7333   NaN        Q   13         1
# 1    male  38.0      0      0  315089   8.6625   NaN        S  NaN         0
# 2  female  30.0      1      1  345773  24.1500   NaN        S  NaN         0
# 3  female  54.0      1      3   29105  23.0000   NaN        S    4         1
# 4    male  40.0      0      0   28221  13.0000   NaN        S  NaN         0
#
#                   home.dest
# ...

# %% [markdown]
# ## data cleansing or munging

# %%
df.drop(['ticket'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-7ee41e58db6e> in <module>
# ----> 1 df.drop(['ticket'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
df.drop(['ticket'], axis=1)
# Out:
#      passenger_id  pclass                                               name  \
# 0            1216       3                                 Smyth, Miss. Julia
# 1             699       3                                    Cacic, Mr. Luka
# 2            1267       3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 3             449       2              Hocking, Mrs. Elizabeth (Eliza Needs)
# 4             576       2                                    Veal, Mr. James
# ..            ...     ...                                                ...
# 845           158       1                        Hipkins, Mr. William Edward
# 846           174       1                            Kent, Mr. Edward Austin
# 847           467       2                Kantor, Mrs. Sinai (Miriam Sternin)
# 848          1112       3                          Peacock, Miss. Treasteall
# 849           425       2                              Greenberg, Mr. Samuel
#
# ...

# %%
df.head()
# Out:
#    passenger_id  pclass                                               name  \
# 0          1216       3                                 Smyth, Miss. Julia
# 1           699       3                                    Cacic, Mr. Luka
# 2          1267       3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 3           449       2              Hocking, Mrs. Elizabeth (Eliza Needs)
# 4           576       2                                    Veal, Mr. James
#
#       sex   age  sibsp  parch  ticket     fare cabin embarked boat  survived  \
# 0  female   NaN      0      0  335432   7.7333   NaN        Q   13         1
# 1    male  38.0      0      0  315089   8.6625   NaN        S  NaN         0
# 2  female  30.0      1      1  345773  24.1500   NaN        S  NaN         0
# 3  female  54.0      1      3   29105  23.0000   NaN        S    4         1
# 4    male  40.0      0      0   28221  13.0000   NaN        S  NaN         0
#
#                   home.dest
# ...

# %%
df.drop(['ticket'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    passenger_id  pclass                                               name  \
# 0          1216       3                                 Smyth, Miss. Julia
# 1           699       3                                    Cacic, Mr. Luka
# 2          1267       3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 3           449       2              Hocking, Mrs. Elizabeth (Eliza Needs)
# 4           576       2                                    Veal, Mr. James
#
#       sex   age  sibsp  parch     fare cabin embarked boat  survived  \
# 0  female   NaN      0      0   7.7333   NaN        Q   13         1
# 1    male  38.0      0      0   8.6625   NaN        S  NaN         0
# 2  female  30.0      1      1  24.1500   NaN        S  NaN         0
# 3  female  54.0      1      3  23.0000   NaN        S    4         1
# 4    male  40.0      0      0  13.0000   NaN        S  NaN         0
#
#                   home.dest
# 0                       NaN
# 1                   Croatia
# ...

# %%
df.set_index('passenger_id')
# Out:
#               pclass                                               name  \
# passenger_id
# 1216               3                                 Smyth, Miss. Julia
# 699                3                                    Cacic, Mr. Luka
# 1267               3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 449                2              Hocking, Mrs. Elizabeth (Eliza Needs)
# 576                2                                    Veal, Mr. James
# ...              ...                                                ...
# 158                1                        Hipkins, Mr. William Edward
# 174                1                            Kent, Mr. Edward Austin
# 467                2                Kantor, Mrs. Sinai (Miriam Sternin)
# 1112               3                          Peacock, Miss. Treasteall
# 425                2                              Greenberg, Mr. Samuel
#
#                  sex   age  sibsp  parch     fare cabin embarked boat  \
# passenger_id
# ...

# %%
df.set_index('passenger_id' , inplace=True)

# %%
df.head()
# Out:
#               pclass                                               name  \
# passenger_id
# 1216               3                                 Smyth, Miss. Julia
# 699                3                                    Cacic, Mr. Luka
# 1267               3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 449                2              Hocking, Mrs. Elizabeth (Eliza Needs)
# 576                2                                    Veal, Mr. James
#
#                  sex   age  sibsp  parch     fare cabin embarked boat  \
# passenger_id
# 1216          female   NaN      0      0   7.7333   NaN        Q   13
# 699             male  38.0      0      0   8.6625   NaN        S  NaN
# 1267          female  30.0      1      1  24.1500   NaN        S  NaN
# 449           female  54.0      1      3  23.0000   NaN        S    4
# 576             male  40.0      0      0  13.0000   NaN        S  NaN
#
#               survived                 home.dest
# passenger_id
# ...

# %% [markdown]
# ## handling missing data (data imputation)

# %% [markdown]
# * fill (by value or by method) the missing data
# * drop the row / column with missing data

# %%
df.info() #information about df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 850 entries, 1216 to 425
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     850 non-null    int64
#  1   name       850 non-null    object
#  2   sex        850 non-null    object
#  3   age        676 non-null    float64
#  4   sibsp      850 non-null    int64
#  5   parch      850 non-null    int64
#  6   fare       849 non-null    float64
#  7   cabin      191 non-null    object
#  8   embarked   849 non-null    object
#  9   boat       308 non-null    object
#  10  survived   850 non-null    int64
#  11  home.dest  464 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 86.3+ KB

# %% [markdown]
# ## Drop

# %%
df_deleted = df.drop(['sex', 'age', 'embarked'] , axis=1)

# %%
df.head()
# Out:
#               pclass                                               name  \
# passenger_id
# 1216               3                                 Smyth, Miss. Julia
# 699                3                                    Cacic, Mr. Luka
# 1267               3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 449                2              Hocking, Mrs. Elizabeth (Eliza Needs)
# 576                2                                    Veal, Mr. James
#
#                  sex   age  sibsp  parch     fare cabin embarked boat  \
# passenger_id
# 1216          female   NaN      0      0   7.7333   NaN        Q   13
# 699             male  38.0      0      0   8.6625   NaN        S  NaN
# 1267          female  30.0      1      1  24.1500   NaN        S  NaN
# 449           female  54.0      1      3  23.0000   NaN        S    4
# 576             male  40.0      0      0  13.0000   NaN        S  NaN
#
#               survived                 home.dest
# passenger_id
# ...

# %%
df_deleted(['sex', 'age', 'embarked'] , axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-3655cc987969> in <module>
# ----> 1 df_deleted(['sex', 'age', 'embarked'] , axis=1)
#
# TypeError: 'DataFrame' object is not callable

# %%
df2 = df.dropna(axis=1) #na-not available/missing values

# %%
df2.head()
# Out:
#               pclass                                               name  \
# passenger_id
# 1216               3                                 Smyth, Miss. Julia
# 699                3                                    Cacic, Mr. Luka
# 1267               3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 449                2              Hocking, Mrs. Elizabeth (Eliza Needs)
# 576                2                                    Veal, Mr. James
#
#                  sex  sibsp  parch  survived
# passenger_id
# 1216          female      0      0         1
# 699             male      0      0         0
# 1267          female      1      1         0
# 449           female      1      3         1
# 576             male      0      0         0

# %%
df.head()
# Out:
#               pclass                                               name  \
# passenger_id
# 1216               3                                 Smyth, Miss. Julia
# 699                3                                    Cacic, Mr. Luka
# 1267               3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 449                2              Hocking, Mrs. Elizabeth (Eliza Needs)
# 576                2                                    Veal, Mr. James
#
#                  sex   age  sibsp  parch     fare cabin embarked boat  \
# passenger_id
# 1216          female   NaN      0      0   7.7333   NaN        Q   13
# 699             male  38.0      0      0   8.6625   NaN        S  NaN
# 1267          female  30.0      1      1  24.1500   NaN        S  NaN
# 449           female  54.0      1      3  23.0000   NaN        S    4
# 576             male  40.0      0      0  13.0000   NaN        S  NaN
#
#               survived                 home.dest
# passenger_id
# ...

# %%
df3 = df.dropna()

# %%
df3.head()
# Out:
#               pclass                                               name  \
# passenger_id
# 43                 1    Bucknell, Mrs. William Robert (Emma Eliza Ward)
# 233                1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 36                 1                        Bowerman, Miss. Elsie Edith
# 249                1                        Ryerson, Master. John Borie
# 275                1  Spedden, Mrs. Frederic Oakley (Margaretta Corn...
#
#                  sex   age  sibsp  parch      fare            cabin embarked  \
# passenger_id
# 43            female  60.0      0      0   76.2917              D15        C
# 233           female  56.0      0      1   83.1583              C50        C
# 36            female  22.0      0      1   55.0000              E33        S
# 249             male  13.0      2      2  262.3750  B57 B59 B63 B66        C
# 275           female  40.0      1      1  134.5000              E34        C
#
# ...

# %%
df3.shape
# Out:
# (104, 12)

# %%
df.shape
# Out:
# (850, 12)

# %% [markdown]
# ## study how to fill in missing data
