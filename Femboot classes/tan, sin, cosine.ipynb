# %%
import numpy as np

# %%
import math

# %%
a=np.random.randint(-20,20,100)
b=np.random.randint(-20,20,100)

# %%
a_tan=np.tan(a)
a_cos=np.cos(a)
a_sin=np.sin(a)
b_tan=np.tan(b)
b_cos=np.cos(b)
b_sin=np.sin(b)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(b_sin, a_sin)

# %%
plt.bar(a_cos, a_tan )
# Out:
# <BarContainer object of 100 artists>

# %%
plt.plot(b_tan, b_cos)

# %%
plt.plot(a_sin,a_tan)

# %%
plt.plot(a_tan,a_cos)

# %%
plt.plot(a_sin,a_tan)
plt.plot(a_tan,a_cos)

# %%
plt.plot(a_sin,a_tan, label='graph of sin a and tan a')
plt.plot(a_tan,a_cos, label='graph of tan a and cos a')
plt.legend()
plt.grid(True)
